# %%
import swat
from time import time
from matplotlib import pyplot as plt

# Importing preprocessed train
import sys
sys.path.append("..")
from Functions.UNSW_DF import *

train, test = DF_original_traintest()
# Out:
# Reading Original CSV Files..
# 	 Train Shape:  	 (175341, 45)
# 	 Test Shape:  	 (82332, 45)
# Dataset Loaded!

# %%
def UNSW_plot_bar(Dataset, x_axis, y_axis):
    # Sets the figure size temporarily but has to be set again the next plot
    plt.figure(figsize=(15,10))
    # Construct plot
    plots = sns.barplot(x = x_axis, y = y_axis, palette = 'magma', data = Dataset)

    for bar in plots.patches:  
    # Using Matplotlib's annotate function and
    # passing the coordinates where the annotation shall be done
    # x-coordinate: bar.get_x() + bar.get_width() / 2
    # y-coordinate: bar.get_height()
    # free space to be left to make graph pleasing: (0, 8)
    # ha and va stand for the horizontal and vertical alignment
        plots.annotate(format(bar.get_height(), '.2f'),
                    (bar.get_x() + bar.get_width() / 2,
                        bar.get_height()), ha='center', va='center',
                    size=15, xytext=(0, 8),
                    textcoords='offset points')
    plt.show()

# %%
Dataframe = pd.DataFrame(train)

# %%
UNSW_plot_bar(train, "attack_cat", "tcp")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5708/3062837750.py in <module>
# ----> 1 UNSW_plot_bar(train, "attack_cat", "tcp")
#
# ~\AppData\Local\Temp/ipykernel_5708/784946936.py in UNSW_plot_bar(Dataset, state, INT)
#       3     plt.figure(figsize=(15,10))
#       4     # Construct plot
# ----> 5     plots = sns.barplot(x = x_axis, y = y_axis, palette = 'magma', data = Dataset)
#       6
#       7     for bar in plots.patches:
#
# NameError: name 'x_axis' is not defined

# %%
train
# Out:
#             id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0            1  0.121478   tcp       -   FIN      6      4     258     172
# 1            2  0.649902   tcp       -   FIN     14     38     734   42014
# 2            3  1.623129   tcp       -   FIN      8     16     364   13186
# 3            4  1.681642   tcp     ftp   FIN     12     12     628     770
# 4            5  0.449454   tcp       -   FIN     10      6     534     268
# ...        ...       ...   ...     ...   ...    ...    ...     ...     ...
# 175336  175337  0.000009   udp     dns   INT      2      0     114       0
# 175337  175338  0.505762   tcp       -   FIN     10      8     620     354
# 175338  175339  0.000009   udp     dns   INT      2      0     114       0
# 175339  175340  0.000009   udp     dns   INT      2      0     114       0
# 175340  175341  0.000009   udp     dns   INT      2      0     114       0
#
# ...
