# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Dataset loading
import sys
sys.path.append("..")
from Functions.UNSW_DF import *

# %%
data = pd.read_csv("../KNN/K_SCORES(1-200).csv")
data.set_index("K", inplace=True)
error = data.error

# %%
plt.figure(figsize=(8, 5))
plt.plot(range(1, 201), error, color='red', linestyle='dashed', marker='o',
         markerfacecolor='blue', markersize=4)
#plt.title('Error Rate K Value')
plt.xlabel('K Value', fontsize=13)
plt.ylabel('Mean Error', fontsize=13)
plt.savefig('KNN(1-200)_v3.png', dpi=600)
plt.show()

# %% [markdown]
# # 1 to 40

# %%
data = pd.read_csv("../KNN/K_SCORES(1-200).csv")
data = data[:40]
data.set_index("K", inplace=True)
error = data.error

# %%
plt.figure(figsize=(8, 5))
plt.plot(range(1, 41), error, color='red', linestyle='dashed', marker='o',
         markerfacecolor='blue', markersize=4)
#plt.title('Error Rate K Value')
plt.xlabel('K Value', fontsize=13)
plt.ylabel('Mean Error', fontsize=13)
plt.savefig('KNN(1-40)_v3.png', dpi=600)
plt.show()
