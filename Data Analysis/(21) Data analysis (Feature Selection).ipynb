# %%
import pandas as np
import numpy as np
import sys
import matplotlib.pyplot as plt
import seaborn as sns

sys.path.append("..")
from Functions.UNSW_DF import *
# Out:
# C:\Users\Sajepan\.conda\envs\MasterThesisGPU\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Sajepan\.conda\envs\MasterThesisGPU\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# C:\Users\Sajepan\.conda\envs\MasterThesisGPU\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
df = pd.read_csv("../Dataset/feature_importance.csv")
plt.xticks(rotation=90)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
UNSW_plot_corr_matrix(dataset=df, fig_x=14, fig_y=14, x_label_rot=0, y_label_rot=0, title="Correlation Matrix - Feature Selection")

# %%
x = df.feature
y = df.drop(["feature"], axis=1)

# %%
sns.set(rc={"figure.figsize":(20, 18), 'axes.facecolor':'white',})

# %%
import seaborn as sns
sns.set_theme(style="ticks")
sns.pairplot(df, hue="train")

# %%
sns.set(rc={"figure.figsize":(20, 12)})
sns.set_style("whitegrid")
plt.xticks(rotation=90)

sns.scatterplot(df['feature'],df['train'], hue =df["mean"])
# Out:
# C:\Users\Sajepan\.conda\envs\MasterThesisGPU\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='feature', ylabel='train'>

# %%
sns.barplot(x ="feature", y ="train", data = df)
# Out:
# <AxesSubplot:xlabel='feature', ylabel='train'>

# %%
sns.set(rc={"figure.figsize":(24, 5), 'axes.facecolor':'white',})
sns.set_style("whitegrid")

fig, axs = plt.subplots(ncols=4, nrows=1)
sns.kdeplot( df['train'], df['train_10_fold'], ax=axs[0])
sns.kdeplot( df['train'], df['combined'], ax=axs[1] )
sns.kdeplot( df['train'], df['combined_10_fold'], ax=axs[2] )
sns.kdeplot( df['train'], df['mean'], ax=axs[3])
# Out:
# C:\Users\Sajepan\.conda\envs\MasterThesisGPU\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Sajepan\.conda\envs\MasterThesisGPU\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
sns.set(rc={"figure.figsize":(24, 5), 'axes.facecolor':'white',})
sns.set_style("whitegrid")

fig, axs = plt.subplots(ncols=5, nrows=1)
ax=sns.distplot(df['train'], ax=axs[0])
ax=sns.distplot(df['train_10_fold'], ax=axs[1])
ax=sns.distplot(df['combined'], ax=axs[2])
ax=sns.distplot(df['combined_10_fold'], ax=axs[3])
ax=sns.distplot(df['mean'], ax=axs[4])

ax.figure.savefig("Feature_selection_distributionplot.png", dpi=400)
# Out:
# C:\Users\Sajepan\.conda\envs\MasterThesisGPU\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Sajepan\.conda\envs\MasterThesisGPU\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.jointplot(data=df, x="train", y="mean", kind="reg")

# %% [markdown]
# ## Regplot with subplots

# %%
sns.set(rc={"figure.figsize":(18, 11)})
sns.set_style("whitegrid")

fig, axs = plt.subplots(ncols=2, nrows=2)
ax=sns.regplot(x='train', y='mean', data=df, ax=axs[0, 0])
ax=sns.regplot(x='train', y='train_10_fold', data=df, ax=axs[0,1])
ax=sns.regplot(x='train', y='combined', data=df, ax=axs[1,0])
ax=sns.regplot(x='train', y='combined_10_fold', data=df, ax=axs[1, 1])

ax.figure.savefig("Feature_selection_regplot.png", dpi=400)

# %%
g = sns.FacetGrid(df, col='mean', row='train', hue='feature', height=5, palette='GnBu')
g = g.map(sns.distplot, 'mean', bins=range(20, 51, 5), kde=True, hist_kws=dict(edgecolor="k", linewidth=1)).add_legend()
plt.show()

# %% [markdown]
# # COMBINING DF

# %%
df_comb = pd.melt(df, id_vars="feature", var_name="metric", value_name="score")

# %%
sns.set(rc={"figure.figsize":(30, 12), 'axes.facecolor':'white',})
sns.set_style("whitegrid")

# %%
plt.xticks(rotation=90)
ax = sns.barplot(x='feature', y='score', hue='metric', data=df_comb, palette="viridis")
#ax.figure.savefig("performance_evaluation_v3.png", dpi=400)

# %%
sns.set(rc={"figure.figsize":(20, 12)})
sns.set_style("whitegrid")
plt.xticks(rotation=90)
sns.lineplot(df_comb['feature'], df_comb['score'], hue = df_comb["metric"])

# %%
sns.set(rc={"figure.figsize":(14, 8)})
sns.set_style("whitegrid")
plt.xticks(rotation=90)

ax = sns.scatterplot(df_comb['feature'],df_comb['score'], hue =df_comb["metric"])
