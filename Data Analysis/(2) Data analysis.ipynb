# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
import swat
from time import time



# Importing preprocessed dataset
import sys
sys.path.append("..")
from Functions.UNSW_DF import *
train, test = DF_original()
# Out:
# Reading Original CSV Files..
# 	 Train Shape:  	 (175341, 45)
# 	 Test Shape:  	 (82332, 45)
# Dataset Loaded!

# %%
num_features = train.columns[train.dtypes != 'object']
fig, axes = plt.subplots(1, 3, figsize=(50, 40), sharey=True, dpi=100)
for i in num_features:
    plt.figure()
    sns.displot(train[i])

# %%
# Correlation plot
corr = train.corr()
sns.set_theme('notebook')

mask = np.triu(np.ones_like(corr, dtype=bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)

plt.figure(figsize=(20,12))
sns.heatmap(corr, mask=mask, cmap=cmap, center=0, square=True, linewidths=1)
plt.savefig('Dataset Correlation.png', dpi=300)
plt.show()

# %%
attack_categories = train.attack_cat.unique()

plt.subplots(figsize=(20,15), dpi=200)

for i in attack_categories:
    sns.distplot(train.loc[train.attack_cat==str(attack_categories[i]), "dur"] , color="dodgerblue", label="Fuzzers")
    #sns.distplot(train.loc[train.attack_cat=='DoS', "dur"] , color="orange", label="DoS")
    #sns.distplot(train.loc[train.attack_cat=='Exploits', "dur"] , color="deeppink", label="Exploits")

plt.title('Histogram')
plt.legend()

# %%
attack_categories = train.attack_cat.unique()

# %%
sns.distplot(train.loc[train.attack_cat==attack_categories[2], "dur"] , color="dodgerblue", label="Fuzzers")

# %%
for i in attack_categories:
    print(attack_categories[i])

# %%
attack_categories = train.attack_cat.unique()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
import swat
from time import time



# Importing preprocessed dataset
import sys
sys.path.append("..")
from Functions.UNSW_DF import *
train, test = DF_original()

# %%
num_features = train.columns[train.dtypes != 'object']
fig, axes = plt.subplots(1, 3, figsize=(50, 40), sharey=True, dpi=100)
for i in num_features:
    plt.figure()
    sns.displot(train[i])

# %%
# Correlation plot
corr = train.corr()
sns.set_theme('notebook')

mask = np.triu(np.ones_like(corr, dtype=bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)

plt.figure(figsize=(20,12))
sns.heatmap(corr, mask=mask, cmap=cmap, center=0, square=True, linewidths=1)
plt.savefig('Dataset Correlation.png', dpi=300)
plt.show()

# %%
attack_categories = train.attack_cat.unique()

plt.subplots(figsize=(20,15), dpi=200)

for i in attack_categories:
    sns.distplot(train.loc[train.attack_cat==str(attack_categories[i]), "dur"] , color="dodgerblue", label="Fuzzers")
    #sns.distplot(train.loc[train.attack_cat=='DoS', "dur"] , color="orange", label="DoS")
    #sns.distplot(train.loc[train.attack_cat=='Exploits', "dur"] , color="deeppink", label="Exploits")

plt.title('Histogram')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18152/2235038823.py in <module>
#       4
#       5 for i in attack_categories:
# ----> 6     sns.distplot(train.loc[train.attack_cat==str(attack_categories[i]), "dur"] , color="dodgerblue", label="Fuzzers")
#       7     #sns.distplot(train.loc[train.attack_cat=='DoS', "dur"] , color="orange", label="DoS")
#       8     #sns.distplot(train.loc[train.attack_cat=='Exploits', "dur"] , color="deeppink", label="Exploits")
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
attack_categories = train.attack_cat.unique()

# %%
sns.distplot(train.loc[train.attack_cat==attack_categories[2], "dur"] , color="dodgerblue", label="Fuzzers")

# %%
for i in attack_categories:
    print(attack_categories[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18152/3046164691.py in <module>
#       1 for i in attack_categories:
# ----> 2     print(attack_categories[i])
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
attack_categories = train.attack_cat.unique()
