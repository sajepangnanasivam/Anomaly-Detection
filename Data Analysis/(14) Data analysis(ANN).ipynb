# %%
import pandas as pd 
import numpy as np
import sys
sys.path.append("..")
from Functions.UNSW_DF import *

# %%
df = pd.read_csv("../ANN/ANN_200E_3L(50-25-1)_AF(Relu-Sigmoid).csv")
df
# Out:
#     epochs  no_layers  accuracy_train  accuracy_test  error_train  error_test  \
# 0        0          3        0.692217       0.566730     0.307783    0.433270
# 1       10          3        0.945346       0.840208     0.054654    0.159792
# 2       20          3        0.947810       0.861731     0.052190    0.138269
# 3       30          3        0.950303       0.874107     0.049697    0.125893
# 4       40          3        0.950611       0.873706     0.049389    0.126294
# 5       50          3        0.950616       0.866310     0.049384    0.133690
# 6       60          3        0.950348       0.878188     0.049652    0.121812
# 7       70          3        0.952732       0.861658     0.047268    0.138342
# 8       80          3        0.953251       0.868350     0.046749    0.131650
# 9       90          3        0.951991       0.871945     0.048009    0.128055
# 10     100          3        0.953126       0.849998     0.046874    0.150002
# ...

# %%
df2 = pd.read_csv("../ANN/ANN_200E_7L(200-150-125-100-50-25-1)_AF(Relu-Sigmoid).csv")
df2
# Out:
#     epochs  no_layers  accuracy_train  accuracy_test  error_train  error_test  \
# 0        0          7        0.293132       0.386545     0.706868    0.613455
# 1       10          7        0.947343       0.846791     0.052657    0.153209
# 2       20          7        0.951152       0.872881     0.048848    0.127119
# 3       30          7        0.952829       0.855354     0.047171    0.144646
# 4       40          7        0.955909       0.862836     0.044091    0.137164
# 5       50          7        0.958173       0.871411     0.041827    0.128589
# 6       60          7        0.961116       0.865204     0.038884    0.134796
# 7       70          7        0.963859       0.859848     0.036141    0.140152
# 8       80          7        0.964977       0.866747     0.035023    0.133253
# 9       90          7        0.968011       0.865508     0.031989    0.134492
# 10     100          7        0.968627       0.868484     0.031373    0.131516
# ...

# %%
df3 = pd.read_csv("../ANN/ANN_200E_11L(300-250-200-175-150-125-100-75-50-25-1)_AF(Relu-Sigmoid).csv")
df3
# Out:
#     epochs  no_layers  accuracy_train  accuracy_test  error_train  error_test  \
# 0        0         11        0.322765       0.443861     0.677235    0.556139
# 1       10         11        0.946225       0.846147     0.053775    0.153853
# 2       20         11        0.947959       0.886205     0.052041    0.113795
# 3       30         11        0.951820       0.878638     0.048180    0.121362
# 4       40         11        0.954318       0.855694     0.045682    0.144306
# 5       50         11        0.955327       0.863747     0.044673    0.136253
# 6       60         11        0.959793       0.857067     0.040207    0.142933
# 7       70         11        0.963095       0.863419     0.036905    0.136581
# 8       80         11        0.961772       0.860382     0.038228    0.139618
# 9       90         11        0.964395       0.862581     0.035605    0.137419
# 10     100         11        0.970355       0.864099     0.029645    0.135901
# ...

# %%
df4 = pd.read_csv("../ANN/ANN_200E_9L(200-175-150-125-100-75-50-25-1)_AF(Relu-Sigmoid).csv")
df4
# Out:
#     epochs  no_layers  accuracy_train  accuracy_test  error_train  error_test  \
# 0        0          9        0.314462       0.441736     0.685538    0.558264
# 1       10          9        0.947331       0.859751     0.052669    0.140249
# 2       20          9        0.951512       0.865872     0.048488    0.134128
# 3       30          9        0.953434       0.859399     0.046566    0.140601
# 4       40          9        0.954152       0.861548     0.045848    0.138452
# 5       50          9        0.957739       0.863455     0.042261    0.136545
# 6       60          9        0.960774       0.865824     0.039226    0.134176
# 7       70          9        0.964657       0.860127     0.035343    0.139873
# 8       80          9        0.964606       0.862241     0.035394    0.137759
# 9       90          9        0.968479       0.862982     0.031521    0.137018
# 10     100          9        0.969454       0.862022     0.030546    0.137978
# ...
