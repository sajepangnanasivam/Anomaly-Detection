# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

import sys
sys.path.append("..")
from Functions.UNSW_DF import *
x_train, x_test, y_train, y_test = DF_XY()
# Out:
# ( 1 ) Reading Preprocessed CSV files..
# 	 Training dataset loaded..
# 	 Testing dataset loaded..
#
# ( 2 ) Loading done, splitting into X and Y..
# 	 ( 2.1 ) x_train Shape:  	 (175341, 53)
# 	 ( 2.2 ) y_train Shape:  	 (175341,)
# 	 ( 2.3 ) x_test Shape:  	 (82332, 53)
# 	 ( 2.4 ) y_test Shape:  	 (82332,)
# ( 3 ) Done!
# PS! Import with: x_train, x_test, y_train, y_test = XY_import()

# %%
df = pd.read_csv("../ANN/ANN_200E_3L(50-25-1)_AF(Relu-Sigmoid).csv")
df2 = pd.read_csv("../ANN/ANN_200E_4L(53-36-21-1)_AF(Relu-Sigmoid).csv")

# %%
df
# Out:
#     epochs  no_layers  accuracy_train  accuracy_test  error_train  error_test  \
# 0        0          3        0.377402       0.359338     0.622598    0.640662
# 1       10          3        0.941406       0.827540     0.058594    0.172460
# 2       20          3        0.948882       0.873804     0.051118    0.126196
# 3       30          3        0.952002       0.869747     0.047998    0.130253
# 4       40          3        0.953188       0.872225     0.046812    0.127775
# 5       50          3        0.955972       0.858378     0.044028    0.141622
# 6       60          3        0.956302       0.876974     0.043698    0.123026
# 7       70          3        0.957614       0.867476     0.042386    0.132524
# 8       80          3        0.958196       0.861670     0.041804    0.138330
# 9       90          3        0.959542       0.864099     0.040458    0.135901
# 10     100          3        0.959080       0.868387     0.040920    0.131613
# ...

# %%
df2
# Out:
#     epochs  no_layers  accuracy_train  accuracy_test  error_train  error_test  \
# 0        0          4        0.325309       0.447019     0.674691    0.552981
# 1       10          4        0.947006       0.860018     0.052994    0.139982
# 2       20          4        0.950012       0.880362     0.049988    0.119638
# 3       30          4        0.953097       0.868059     0.046903    0.131941
# 4       40          4        0.955356       0.852135     0.044644    0.147865
# 5       50          4        0.958390       0.856289     0.041610    0.143711
# 6       60          4        0.959770       0.867706     0.040230    0.132294
# 7       70          4        0.961680       0.868581     0.038320    0.131419
# 8       80          4        0.962673       0.863091     0.037327    0.136909
# 9       90          4        0.963551       0.867852     0.036449    0.132148
# 10     100          4        0.965815       0.868957     0.034185    0.131043
# ...

# %%
df = df.drop("runtime(s)", axis=1)
df = df.drop("epochs", axis=1)

# %%
df = df.drop("no_layers", axis=1)

# %%
df = df.drop("error_train", axis=1)
df = df.drop("error_test", axis=1)

# %%
UNSW_barplot(data=df, to_range=len(df), x_label="Score", y_label="Value", title="ANN Scores", x_size=40, y_size=15,)
